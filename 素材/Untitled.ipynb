# %%
import cv2

o = cv2.imread("lenaNoise.png")

r1 = cv2.boxFilter(o, cv2.CV_16U, (5, 5), normalize=0)
r2 = cv2.boxFilter(o, cv2.CV_16U, (16, 16), normalize=0)
r3 = r1 * 10

cv2.imshow("original", o)
cv2.imshow("result1", r1)
cv2.imshow("result2", r2)
cv2.imshow("result3", r3)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#      11 cv2.imshow("result2", r2)
#      12 cv2.imshow("result3", r3)
# ---> 14 cv2.waitKey()
#      15 cv2.destroyAllWindows()
#
# KeyboardInterrupt:
